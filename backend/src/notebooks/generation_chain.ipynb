# %% [markdown]
# ## Generation Chain

# %%
USER_PROMPT = """
You are an expert content writer in LinkedIn. Your job is to understand the user's query and transform the query for more clarity.
After that add all the relevant details to the query for better engaging content. Your goal is  to just transform the query and return only
the transformed query. Where we will pass the transformed query to an LLM to generate the post.
"""

# %%
from dotenv import load_dotenv
load_dotenv()
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

prompt = ChatPromptTemplate.from_messages([
    ("system", USER_PROMPT),
    ("user", "Write a post about the following topic: {query}"),
])

transformed_query_agent = prompt | llm | StrOutputParser()

# %%
transformed_query = transformed_query_agent.invoke({"query": "Write a post about how I turn from a supermarket sales boy to an Software Engineer."})

# %%
SYSTEM_PROMPT = """
You are a senior LinkedIn content creator who understands how real people read and engage on LinkedIn.

Your task is to write a LinkedIn post based on the given topic.

Guidelines:
- Write in a natural, human tone — conversational, clear, and authentic.
- Use short paragraphs (1–2 lines max) to improve readability on mobile.
- Avoid corporate jargon, buzzwords, emojis overload, or motivational clichés.
- Do NOT sound like an AI, marketer, or coach.
- Write like a real professional sharing a genuine insight or experience.
- Create a strong hook in the first 2–3 lines that makes people stop scrolling.
- Maintain emotional honesty where relevant, but keep it grounded and practical.
- End with a soft reflection or thought-provoking line (not a forced CTA).

The post should feel personal, relatable, and written by a human — not generated.
"""

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", SYSTEM_PROMPT),
    ("user", "Write a post about the following topic: {query}"),
])

generate_query_agent = prompt | llm | StrOutputParser()

# %%
generate_query_agent.invoke({"query": transformed_query})
# Out:
# 'A few years ago, I was standing behind a checkout counter, scanning groceries and chatting with customers. It was a good job, but deep down, I felt a pull toward something more. \n\nTransitioning from a supermarket sales associate to a software engineer wasn’t a straight path. It was filled with late nights, online courses, and moments of self-doubt. I remember the first time I tried to code a simple program. It felt like trying to learn a new language while running a marathon. \n\nBut every challenge taught me something valuable. I learned to break down complex problems into manageable parts—skills I honed while helping customers find the right products. That same problem-solving mindset became my greatest asset in tech. \n\nThere were pivotal moments, too. Like the time I built my first app. The sense of accomplishment was overwhelming. It fueled my passion and made all those late nights worth it. \n\nPerseverance and continuous learning became my mantra. I realized that every setback was just a stepping stone. The work ethic I developed in retail—showing up, being reliable, and putting in the effort—translated seamlessly into my new career. \n\nIf you’re considering a career change, know that it’s possible. Embrace the learning process, and don’t shy away from the challenges. Your past experiences can shape your future in ways you might not expect. \n\nSometimes, the most unexpected journeys lead to the most fulfilling destinations.'
